# %% [markdown]
# #                            Global Covid-19 analysis

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode,  plot


import plotly.io as pio
pio.renderers.default='browser'

# %% [markdown]
# made a dataframe from csv files

# %%
confirmed_cases = pd.read_csv('time_series_covid19_confirmed_global.csv')
print(confirmed_cases.shape)
deaths_cases = pd.read_csv('time_series_covid19_deaths_global.csv')
print(deaths_cases.shape)
recovered_cases = pd.read_csv('time_series_covid19_recovered_global.csv')
print(recovered_cases.shape)

#total_cases = pd.read_csv('confirmed_cases.csv')
total_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')
print(total_cases.shape)
# Out:
# (266, 125)
# (266, 125)
# (253, 125)
# (188, 14)

# %% [markdown]
# made a copy of total cases and dropped columns which weren't required for analysis

# %%
global_cases = total_cases
global_cases = global_cases.drop(['Last_Update','Lat','Long_','Incident_Rate','People_Tested','People_Hospitalized',
                                  'Mortality_Rate','UID','ISO3'],axis=1)

global_cases_sum = pd.DataFrame(global_cases.sum()).transpose()

# %% [markdown]
# Converted scientific notation to integer

# %%
global_cases_sum['Confirmed'] = global_cases_sum['Confirmed'].astype('int64') 
global_cases_sum['Active'] = global_cases_sum['Active'].astype('int64') 
global_cases_sum['Deaths'] = global_cases_sum['Deaths'].astype('int64') 
global_cases_sum['Recovered'] = global_cases_sum['Recovered'].astype('int64')

# %% [markdown]
# Dropped columns not required

# %%
confirmed_cases = confirmed_cases.drop(['Lat','Long'],axis=1)
deaths_cases = deaths_cases.drop(['Lat','Long'],axis=1)
recovered_cases = recovered_cases.drop(['Lat','Long'],axis=1)

# %% [markdown]
# only saved dates and cases on that day globally

# %%
total_confirmed_cases = confirmed_cases
total_confirmed_cases = total_confirmed_cases.drop(['Province/State','Country/Region'],axis=1)
total_confirmed_cases_sum = pd.DataFrame(total_confirmed_cases.sum()) 

x =  total_confirmed_cases_sum.index
y1 = total_confirmed_cases_sum.values

#x = pd.DataFrame(x)
y1 = pd.DataFrame(y1)

#x.columns = ['date']
#y.columns = ['cases']

# %%
total_death_cases = deaths_cases
total_death_cases = total_death_cases.drop(['Province/State','Country/Region'],axis=1)
total_death_cases_sum = pd.DataFrame(total_death_cases.sum()) 

x2 =  total_death_cases_sum.index
y2 = total_death_cases_sum.values

y2 = pd.DataFrame(y2)

# %%
total_recovered_cases = recovered_cases
total_recovered_cases = total_recovered_cases.drop(['Province/State','Country/Region'],axis=1)
total_recovered_cases_sum = pd.DataFrame(total_recovered_cases.sum()) 

x3 =  total_recovered_cases_sum.index
y3 = total_recovered_cases_sum.values

y3 = pd.DataFrame(y3)

# %%
y4= np.abs(y1[0]-y2[0]-y3[0])
y4= pd.DataFrame(y4)

# %%
fig = go.Figure()
for col in y1.columns:
    fig.add_trace(go.Scatter(x=total_confirmed_cases_sum.index , y = y1[col], name='Confirmed',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_death_cases_sum.index , y = y2[col],name='Deaths',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_recovered_cases_sum.index , y = y3[col],name='Recovered',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_death_cases_sum.index , y = y4[col],name='Active',mode='lines+markers'))
fig.show()

# %%
# **************************************************************************************************************

# %%
global_cases_colored_dataframe = global_cases

global_cases_colored_dataframe['Confirmed'] = global_cases_colored_dataframe['Confirmed'].astype('int64') 
global_cases_colored_dataframe['Active'] = global_cases_colored_dataframe['Active'].astype('int64') 
global_cases_colored_dataframe['Deaths'] = global_cases_colored_dataframe['Deaths'].astype('int64') 
global_cases_colored_dataframe['Recovered'] = global_cases_colored_dataframe['Recovered'].astype('int64') 


global_cases_colored_dataframe.sort_values('Confirmed',ascending = False).reset_index(drop=True).style.bar(align='left',width= 90, color= 'brown',subset=['Confirmed']).bar(align='left',width= 90, color= 'red',subset=['Deaths']).bar(align='left',width= 90, color= 'lawngreen',subset=['Recovered']).bar(align='left',width= 90, color= 'yellow',subset=['Active'])




#.set_properties(**{'background-color': 'black',
#                           'color': 'lawngreen',
#                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 90.0%, transparent 90.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 90.0%, transparent 90.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 90.0%, transparent 90.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 90.0%, transparent 90.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 20.3%, transparent 20.3%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 21.5%, transparent 21.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 36.5%, transparent 36.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 14.6%, transparent 14.6%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 19.1%, transparent 19.1%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 3.3%, transparent 3.3%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 28.2%, transparent 28.2%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 17.1%, transparent 17.1%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 14.2%, transparent 14.2%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 33.9%, transparent 33.9%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 0.3%, transparent 0.3%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 16.6%, transparent 16.6%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 12.7%, transparent 12.7%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 24.6%, transparent 24.6%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 35.7%, transparent 35.7%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 4.3%, transparent 4.3%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 12.5%, transparent 12.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 30.1%, transparent 30.1%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 33.7%, transparent 33.7%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 4.1%, transparent 4.1%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 9.9%, transparent 9.9%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 26.1%, transparent 26.1%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 15.5%, transparent 15.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.6%, transparent 6.6%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 9.8%, transparent 9.8%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.6%, transparent 7.6%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 38.3%, transparent 38.3%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.8%, transparent 0.8%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 8.5%, transparent 8.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 4.0%, transparent 4.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 28.5%, transparent 28.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 2.5%, transparent 2.5%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 7.9%, transparent 7.9%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 3.8%, transparent 3.8%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 14.4%, transparent 14.4%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.0%, transparent 6.0%);
#         }    #T_4506f880_9f81_11ea_9cf2_9c7bef2016b1row10_col1 {
#             width:  10em;
