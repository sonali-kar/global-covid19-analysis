# %% [markdown]
# #                            Global Covid-19 analysis

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode,  plot


import plotly.io as pio
pio.renderers.default='browser'

# %% [markdown]
# made a dataframe from csv files

# %%
confirmed_cases = pd.read_csv('time_series_covid19_confirmed_global.csv')
print(confirmed_cases.shape)
deaths_cases = pd.read_csv('time_series_covid19_deaths_global.csv')
print(deaths_cases.shape)
recovered_cases = pd.read_csv('time_series_covid19_recovered_global.csv')
print(recovered_cases.shape)

#total_cases = pd.read_csv('confirmed_cases.csv')
total_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')
print(total_cases.shape)
# Out:
# (266, 125)
# (266, 125)
# (253, 125)
# (188, 14)

# %% [markdown]
# made a copy of total cases and dropped columns which weren't required for analysis

# %%
global_cases = total_cases
global_cases = global_cases.drop(['Last_Update','Lat','Long_','Incident_Rate','People_Tested','People_Hospitalized',
                                  'Mortality_Rate','UID','ISO3'],axis=1)

global_cases_sum = pd.DataFrame(global_cases.sum()).transpose()

# %% [markdown]
# Converted scientific notation to integer

# %%
global_cases_sum['Confirmed'] = global_cases_sum['Confirmed'].astype('int64') 
global_cases_sum['Active'] = global_cases_sum['Active'].astype('int64') 
global_cases_sum['Deaths'] = global_cases_sum['Deaths'].astype('int64') 
global_cases_sum['Recovered'] = global_cases_sum['Recovered'].astype('int64')

# %% [markdown]
# Dropped columns not required

# %%
confirmed_cases = confirmed_cases.drop(['Lat','Long'],axis=1)
deaths_cases = deaths_cases.drop(['Lat','Long'],axis=1)
recovered_cases = recovered_cases.drop(['Lat','Long'],axis=1)

# %% [markdown]
# only saved dates and cases on that day globally

# %%
total_confirmed_cases = confirmed_cases
total_confirmed_cases = total_confirmed_cases.drop(['Province/State','Country/Region'],axis=1)
total_confirmed_cases_sum = pd.DataFrame(total_confirmed_cases.sum()) 

x =  total_confirmed_cases_sum.index
y1 = total_confirmed_cases_sum.values

#x = pd.DataFrame(x)
y1 = pd.DataFrame(y1)

#x.columns = ['date']
#y.columns = ['cases']

# %%
total_death_cases = deaths_cases
total_death_cases = total_death_cases.drop(['Province/State','Country/Region'],axis=1)
total_death_cases_sum = pd.DataFrame(total_death_cases.sum()) 

x2 =  total_death_cases_sum.index
y2 = total_death_cases_sum.values

y2 = pd.DataFrame(y2)

# %%
total_recovered_cases = recovered_cases
total_recovered_cases = total_recovered_cases.drop(['Province/State','Country/Region'],axis=1)
total_recovered_cases_sum = pd.DataFrame(total_recovered_cases.sum()) 

x3 =  total_recovered_cases_sum.index
y3 = total_recovered_cases_sum.values

y3 = pd.DataFrame(y3)

# %%
y4= np.abs(y1[0]-y2[0]-y3[0])
y4= pd.DataFrame(y4)

# %%
fig = go.Figure()
for col in y1.columns:
    fig.add_trace(go.Scatter(x=total_confirmed_cases_sum.index , y = y1[col], name='Confirmed',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_death_cases_sum.index , y = y2[col],name='Deaths',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_recovered_cases_sum.index , y = y3[col],name='Recovered',mode='lines+markers'))
    fig.add_trace(go.Scatter(x=total_death_cases_sum.index , y = y4[col],name='Active',mode='lines+markers'))
fig.show()

# %%
# **************************************************************************************************************

# %%
global_cases_colored_dataframe = global_cases

global_cases_colored_dataframe['Confirmed'] = global_cases_colored_dataframe['Confirmed'].astype('int64') 
global_cases_colored_dataframe['Active'] = global_cases_colored_dataframe['Active'].astype('int64') 
global_cases_colored_dataframe['Deaths'] = global_cases_colored_dataframe['Deaths'].astype('int64') 
global_cases_colored_dataframe['Recovered'] = global_cases_colored_dataframe['Recovered'].astype('int64') 


global_cases_colored_dataframe.sort_values('Confirmed',ascending = False).reset_index(drop=True).style.bar(align='left',width= 90, color= 'brown',subset=['Confirmed']).bar(align='left',width= 90, color= 'red',subset=['Deaths']).bar(align='left',width= 90, color= 'lawngreen',subset=['Recovered']).bar(align='left',width= 90, color= 'yellow',subset=['Active'])




#.set_properties(**{'background-color': 'black',
#                           'color': 'lawngreen',
#                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 90.0%, transparent 90.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 90.0%, transparent 90.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 90.0%, transparent 90.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 90.0%, transparent 90.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 25.8%, transparent 25.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 25.3%, transparent 25.3%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 41.8%, transparent 41.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 19.3%, transparent 19.3%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 20.8%, transparent 20.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 4.2%, transparent 4.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 35.6%, transparent 35.6%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 16.2%, transparent 16.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 13.8%, transparent 13.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 33.2%, transparent 33.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 0.2%, transparent 0.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 16.4%, transparent 16.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 12.0%, transparent 12.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 23.4%, transparent 23.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 30.4%, transparent 30.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 4.3%, transparent 4.3%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 11.7%, transparent 11.7%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 28.8%, transparent 28.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 32.0%, transparent 32.0%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 2.9%, transparent 2.9%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 9.9%, transparent 9.9%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 4.8%, transparent 4.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 19.1%, transparent 19.1%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.7%, transparent 6.7%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 9.5%, transparent 9.5%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 24.8%, transparent 24.8%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 13.9%, transparent 13.9%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.4%, transparent 6.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 9.2%, transparent 9.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.4%, transparent 7.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 33.5%, transparent 33.5%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.6%, transparent 0.6%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,brown 8.2%, transparent 8.2%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 3.9%, transparent 3.9%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lawngreen 13.6%, transparent 13.6%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.4%, transparent 6.4%);
#         }    #T_58c0d6d0_a428_11ea_865b_9c7bef2016b1row10_col1 {
#             width:  10em;

# %%
from sklearn.model_selection import train_test_split


x_lr=x.values
y_lr=y1.values


X_train, X_test, y_train, y_test = train_test_split(x_lr, y_lr, test_size=0.33, random_state=42)

# %%
# Out:
# ['2/24/20' '2/16/20' '3/31/20' '2/19/20' '5/17/20' '4/16/20' '1/27/20'
#  '4/22/20' '3/30/20' '3/1/20' '3/11/20' '2/26/20' '2/7/20' '3/28/20'
#  '2/25/20' '5/15/20' '1/29/20' '3/5/20' '4/3/20' '3/29/20' '4/14/20'
#  '2/18/20' '2/10/20' '4/27/20' '5/2/20' '1/30/20' '2/4/20' '4/15/20'
#  '1/25/20' '2/8/20' '2/29/20' '4/24/20' '1/28/20' '4/8/20' '5/6/20'
#  '4/26/20' '3/16/20' '3/12/20' '4/11/20' '3/8/20' '4/12/20' '3/23/20'
#  '5/18/20' '4/10/20' '4/25/20' '3/3/20' '3/20/20' '3/10/20' '4/19/20'
#  '5/13/20' '3/19/20' '4/6/20' '2/23/20' '5/14/20' '3/21/20' '3/25/20'
#  '5/1/20' '2/28/20' '2/20/20' '5/8/20' '1/23/20' '3/14/20' '2/12/20'
#  '1/24/20' '2/14/20' '5/4/20' '4/30/20' '4/18/20' '5/10/20' '4/5/20'
#  '4/17/20' '4/13/20' '5/21/20' '2/11/20' '3/22/20' '4/2/20' '5/7/20'
#  '2/5/20' '4/23/20' '3/13/20' '5/3/20'] [[  79561]
#  [  71224]
#  [ 857608]
#  [  75639]
#  [4713620]
#  [2152181]
#  [   2927]
#  [2624608]
#  [ 782816]
#  [  88369]
#  [ 125879]
#  [  81388]
#  [  34391]
#  [ 661174]
#  [  80406]
#  [4542347]
#  [   6166]
#  [  97888]
#  [1096324]
#  [ 720291]
#  [1975566]
#  [  75136]
#  [  42762]
#  [3023722]
#  [3427584]
#  [   8234]
#  [  23892]
#  [2055748]
#  [   1434]
#  [  37120]
#  [  86011]
#  [2795731]
#  [   5578]
#  [1480232]
#  [3756069]
#  [2955033]
#  [ 181653]
#  [ 131007]
#  [1736412]
#  [ 109822]
#  [1835145]
#  [ 378301]
#  [4801943]
#  [1658261]
#  [2881140]
#  [  92840]
#  [ 272264]
#  [ 118623]
#  [2400787]
#  [4347018]
#  [ 242632]
#  [1321436]
#  [  78958]
#  [4442163]
#  [ 304580]
#  [ 467817]
#  [3345558]
#  [  84112]
#  [  76197]
#  [3938064]
#  [    654]
#  [ 156120]
#  [  45221]
#  [    941]
#  [  66885]
#  [3583055]
#  [3256910]
#  [2317636]
#  [4101699]
#  [1249743]
#  [2239990]
#  [1905165]
#  [5102424]
#  [  44802]
#  [ 337022]
#  [1013863]
#  [3845718]
#  [  27635]
#  [2708403]
#  [ 145225]
#  [3506729]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-1437160d2f63> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 linear_model = LinearRegression(normalize=True, fit_intercept=True)
# ----> 3 linear_model.fit(X_train,y_train)
#       4 test_linear_pred = linear_model.predict(X_test)
#       5 linear_pred = linear_model.predict(future_forcast)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: '2/24/20'

# %%
dates = data[‘data’]
date_format = [pd.to_datetime(d) for d in dates]
